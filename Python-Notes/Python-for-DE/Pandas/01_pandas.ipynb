# %% [markdown]
# # Pandas

# %% [markdown]
# # it's important it consume 80% time

# %%
# !pip install pandas
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# # Creating Series

# %%
import numpy as np

# %%
ar1 = np.random.randint(30,100,10)
print(pd.Series(ar1))
# Out:
# 0    91
# 1    91
# 2    81
# 3    73
# 4    45
# 5    85
# 6    43
# 7    80
# 8    78
# 9    66
# dtype: int32

# %%
arr = np.random.randint(30,100,15).reshape(3,5)
arr
# Out:
# array([[33, 89, 69, 35, 84],
#        [32, 71, 54, 67, 79],
#        [66, 62, 72, 61, 46]], dtype=int32)

# %%
s = pd.DataFrame(arr,index = ["A","B","C"], columns = ["Ma","Sc","HI","Env","En"])
print(s)
# Out:
#    Ma  Sc  HI  Env  En
# A  33  89  69   35  84
# B  32  71  54   67  79
# C  66  62  72   61  46

# %%
s
# Out:
#    Ma  Sc  HI  Env  En
# A  33  89  69   35  84
# B  32  71  54   67  79
# C  66  62  72   61  46

# %%
s.head(1)
# Out:
#    Ma  Sc  HI  Env  En
# A  33  89  69   35  84

# %%
s.head(2)
# Out:
#    Ma  Sc  HI  Env  En
# A  33  89  69   35  84
# B  32  71  54   67  79

# %%
s.tail(1)
# Out:
#    Ma  Sc  HI  Env  En
# C  66  62  72   61  46

# %%
s.sample(2)
# Out:
#    Ma  Sc  HI  Env  En
# B  32  71  54   67  79
# C  66  62  72   61  46

# %%
s
# Out:
#    Ma  Sc  HI  Env  En
# A  33  89  69   35  84
# B  32  71  54   67  79
# C  66  62  72   61  46

# %%
print(s.loc["C","HI"])
# Out:
# 72

# %%
s.loc["C"]
# Out:
# Ma     66
# Sc     62
# HI     72
# Env    61
# En     46
# Name: C, dtype: int32

# %%
print(s)
# Out:
#    Ma  Sc  HI  Env  En
# A  33  89  69   35  84
# B  32  71  54   67  79
# C  66  62  72   61  46
